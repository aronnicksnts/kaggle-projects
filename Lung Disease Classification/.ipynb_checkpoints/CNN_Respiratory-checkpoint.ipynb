# %%
#Data Sampling
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(os.getcwd()+"\\Respiratory_Sound_Database\\Respiratory_Sound_Database\\"+r'patient_diagnosis.csv')
df.columns = ['patient_num','diagnosis']

plt.bar(df['diagnosis'].value_counts().index, df['diagnosis'].value_counts())
plt.title('Respiratory Sound Database Distribution', fontsize=15)
plt.xlabel('Diagnosis', fontsize=14)
plt.xticks(rotation=45)
plt.show()
print(df['diagnosis'].value_counts())
# Out:
# COPD              64
# Healthy           26
# URTI              13
# Bronchiectasis     7
# Pneumonia          6
# Bronchiolitis      6
# LRTI               2
# Asthma             1
# Name: diagnosis, dtype: int64

# %%
#Get WAV_File
# Out:
# COPD              64
# Healthy           26
# URTI              13
# Bronchiectasis     7
# Pneumonia          6
# Bronchiolitis      6
# LRTI               2
# Asthma             1
# Name: diagnosis, dtype: int64
